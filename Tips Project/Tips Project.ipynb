# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
# Display top 5 rows

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# Display Last 5 rows

# %%
df.tail(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
# Describe Csv Data

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
# Checking for null Values

# %%
df.isnull()
# Out:
#      total_bill    tip    sex  smoker    day   time   size  price_per_person  \
# 0         False  False  False   False  False  False  False             False
# 1         False  False  False   False  False  False  False             False
# 2         False  False  False   False  False  False  False             False
# 3         False  False  False   False  False  False  False             False
# 4         False  False  False   False  False  False  False             False
# ..          ...    ...    ...     ...    ...    ...    ...               ...
# 239       False  False  False   False  False  False  False             False
# 240       False  False  False   False  False  False  False             False
# 241       False  False  False   False  False  False  False             False
# 242       False  False  False   False  False  False  False             False
# 243       False  False  False   False  False  False  False             False
#
#      Payer Name  CC Number  Payment ID
# ...

# %%
df.isnull().sum()
# Out:
# total_bill          0
# tip                 0
# sex                 0
# smoker              0
# day                 0
# time                0
# size                0
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# total_bill          0
# tip                 0
# sex                 0
# smoker              0
# day                 0
# time                0
# size                0
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# total_bill          0
# tip                 0
# sex                 0
# smoker              0
# day                 0
# time                0
# size                0
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
# Distribution of total bill and tip amount

# %%
# Relationship between total_bill and tip

# %%
sns.scatterplot(x='total_bill', y='tip', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(df['total_bill'],kde=True,color='r')
sns.histplot(df['tip'], kde=True,color='g')
sns.scatterplot(x='total_bill', y='tip', data=df,color='m')
plt.show()

# %%
# Data Cleaning

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df['sex']=df['sex'].map({'Female':0,'Male':1})
df['smoker']=df['smoker'].map({'No':0,'Yes':1})

# %%
# Boxplot to check the distribution of tips by day

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='day', y='tip', data=df,palette='Accent')
plt.title('Distribution of Tips by Day')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6296\1413885541.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='tip', data=df,palette='Accent')

# %%
# Plot a scatter plot of total bill vs tip

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='total_bill', y='tip',hue='sex', data=df,palette='BuPu')
plt.title('Total Bill vs Tip')
plt.show()

# %%
# Count plot for the sex variable

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x='sex', data=df,linewidth=0.25,width=0.25,palette=['r','grey'])
plt.title('Count of Diners by Sex')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6296\1630987762.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=df,linewidth=0.25,width=0.25,palette=['r','grey'])

# %%
# Question 1: What is the average tip for each day of the week?

# %%
avg_tip_by_day = df.groupby('day')['tip'].mean()
print(avg_tip_by_day)
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
#Question 2: What is the relationship between the total bill and the tip?

# %%
correlation = df['total_bill'].corr(df['tip'])
print(f"The correlation between total bill and tip is: {correlation:.2f}")
# Out:
# The correlation between total bill and tip is: 0.68

# %%
#Question 3: What is the average bill amount by gender?

# %%
avg_bill_by_sex = df.groupby('sex')['total_bill'].mean()
print(avg_bill_by_sex)
# Out:
# sex
# 0    18.056897
# 1    20.744076
# Name: total_bill, dtype: float64

# %%
#Question 4: How does the tip amount vary based on the time of day (Lunch or Dinner)?

# %%
avg_tip_by_time = df.groupby('time')['tip'].mean()
print(avg_tip_by_time)
# Out:
# time
# Dinner    3.102670
# Lunch     2.728088
# Name: tip, dtype: float64

# %%
#Question 5: What is the proportion of tips given for different sizes of parties?

# %%
tip_by_size = df.groupby('size')['tip'].mean()
print(tip_by_size)
# Out:
# size
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %%
#Question 6: How do tips vary based on the restaurant day of the week?

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='day', y='tip', data=df,palette='BuPu')
plt.title('Tips by Day')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6296\2365754634.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='tip', data=df,palette='BuPu')

# %%
#Question 7: Is there a noticeable difference in tips based on whether customers are male or female?

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='sex', y='tip', data=df)
plt.title('Tip Distribution by Sex')
plt.show()

# %%
#Question 8: Does the total bill amount increase as the party size grows?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='size', y='total_bill', data=df)
plt.title('Total Bill vs Party Size')
plt.show()

# %%
# Question 9: What percentage of customers leave a tip less than $2?

# %%
tip_less_than_2 = df[df['tip'] < 2].shape[0] / df.shape[0] * 100
print(f"Percentage of customers leaving a tip less than $2: {tip_less_than_2:.2f}%")
# Out:
# Percentage of customers leaving a tip less than $2: 18.44%

# %%
# Question 10: What are the most common sizes of parties?

# %%
party_sizes = df['size'].value_counts()
print(party_sizes)
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
# single color for all bars using the color parameter

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=df, color='skyblue')  
plt.title('Count of Diners by Sex')
plt.show()

# %%
#  Different Colors for Each Category

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=df, palette='Set2')
plt.title('Count of Diners by Sex')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6296\3233576907.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=df, palette='Set2')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=df, palette=['lightcoral', 'skyblue']) 
plt.title('Count of Diners by Sex')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6296\3782540467.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=df, palette=['lightcoral', 'skyblue'])

# %%
#  Custom Colors Using Hex Codes

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=df, palette=['#FF6347', '#4682B4'],saturation=75)
plt.title('Count of Diners by Sex')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6296\3653644416.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=df, palette=['#FF6347', '#4682B4'],saturation=75)

# %%
# Using hue for Grouping and Coloring

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=df, hue='smoker', palette='coolwarm')  
plt.title('Count of Diners by Sex and Smoking Status')
plt.show()

# %%
custom_palette = sns.color_palette(["#FF6347", "#4682B4", "#32CD32", "#FFD700"])
# Count plot with a custom palette
plt.figure(figsize=(8, 6))
sns.countplot(x='day', data=df, palette=custom_palette)  # Multiple colors for days
plt.title('Count of Diners by Day')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6296\2301622942.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='day', data=df, palette=custom_palette)  # Multiple colors for days

# %%
# Using hue and Custom Palette for Multiple Colors

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=df, hue='smoker', palette=['#FF6347', '#4682B4'])
plt.title('Count of Diners by Sex and Smoking Status')
plt.show()

# %%
 # Using edgecolor to Set the Line Color

# %%
# Count plot with a specific line color for the edges of the bars
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=df, color='red', edgecolor='grey',linewidth=1.65,width=0.25)  # Set line color to black
plt.title('Count of Diners by Sex')
plt.show()

# %%
# Using edgecolor with Custom Colors

# %%
plt.figure(figsize=(4, 4))
sns.countplot(x='sex', data=df, color='grey', edgecolor='#FF6347',width=0.25)
plt.title('Count of Diners by Sex')
plt.show()

# %%
# Using edgecolor with a Custom Palette and Different Line Colors

# %%
plt.figure(figsize=(4, 6))
sns.countplot(x='sex', data=df, palette=['#FF6347', '#4682B4'], edgecolor='black')
plt.title('Count of Diners by Sex')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6296\3488797500.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=df, palette=['#FF6347', '#4682B4'], edgecolor='black')

# %%
 # Adjusting Edge Color for Multiple Categories

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=df, hue='smoker', palette='Set2', edgecolor='black')  
plt.title('Count of Diners by Sex and Smoking Status')
plt.show()

# %%
#  Aligning Bars in Count Plot

# %%
# Horizontal count plot with alignment
plt.figure(figsize=(4, 3))
sns.countplot(y='day', data=df, palette=["#FF6347", "#4682B4", "#32CD32", "#FFD700"], align='center')  # Center-align the bars
plt.title('Count of Diners by Day')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6296\1955845496.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='day', data=df, palette=["#FF6347", "#4682B4", "#32CD32", "#FFD700"], align='center')  # Center-align the bars

# %%
#Align Bars in a Stacked Count Plot

# %%
plt.figure(figsize=(4, 3))
sns.countplot(x='day', data=df, palette='Set2', hue='smoker', )
plt.title('Count of Diners by Day and Smoking Status')
plt.show()
