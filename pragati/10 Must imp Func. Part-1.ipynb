# %%
import pandas as pd
data = {'age': [25, 22, 18, 30, 45, 50, 35, 20, 55, 40],
        'gender': ['M', 'F', 'F', 'M', 'M', 'F', 'M', 'F', 'M', 'M'],
        'score': [90, 80, 75, 95, 70, 85, 75, 90, 95, 85]}
df = pd.DataFrame(data)

# %%
### 1. value_counts()

# %%
df['gender'].value_counts()
# Out:
# gender
# M    6
# F    4
# Name: count, dtype: int64

# %%
df['gender'].value_counts(normalize= True)
# Out:
# gender
# M    0.6
# F    0.4
# Name: proportion, dtype: float64

# %%
df
# Out:
#    age gender  score
# 0   25      M     90
# 1   22      F     80
# 2   18      F     75
# 3   30      M     95
# 4   45      M     70
# 5   50      F     85
# 6   35      M     75
# 7   20      F     90
# 8   55      M     95
# 9   40      M     85

# %%
##Where

# %%
df[df.where(df['age']>30,other=0).all(1)]
# Out:
#    age gender  score gender_lower  age_squared  age_squared_uf
# 4   45      M     70            m         2025            2025
# 5   50      F     85            f         2500            2500
# 6   35      M     75            m         1225            1225
# 8   55      M     95            m         3025            3025
# 9   40      M     85            m         1600            1600

# %%
f1 = df['age']>30
f2 = df['gender']=="M"

# %%
df[df.where(f1 & f2,other=0).all(1)]
# Out:
#    age gender  score
# 4   45      M     70
# 6   35      M     75
# 8   55      M     95
# 9   40      M     85

# %%
df
# Out:
#    age gender  score
# 0   25      M     90
# 1   22      F     80
# 2   18      F     75
# 3   30      M     95
# 4   45      M     70
# 5   50      F     85
# 6   35      M     75
# 7   20      F     90
# 8   55      M     95
# 9   40      M     85

# %%
#Isin

# %%
df[df['age'].isin([25,35])]
# Out:
#    age gender  score gender_lower  age_squared  age_squared_uf
# 0   25      M     90            m          625             625
# 6   35      M     75            m         1225            1225

# %%
df[df[['age','gender']].isin({'age':[25,35],'gender':['M']}).all(1)]
# Out:
#    age gender  score
# 0   25      M     90
# 6   35      M     75

# %%
df
# Out:
#    age gender  score
# 0   25      M     90
# 1   22      F     80
# 2   18      F     75
# 3   30      M     95
# 4   45      M     70
# 5   50      F     85
# 6   35      M     75
# 7   20      F     90
# 8   55      M     95
# 9   40      M     85

# %%
#Cut And Qcut

# %%
df['score_bins']=pd.cut(df['score'],bins=[60,70,80,85,90,100])

# %%
df
# Out:
#    age gender  score gender_lower  age_squared  age_squared_uf score_bins
# 0   25      M     90            m          625             625   (85, 90]
# 1   22      F     80            f          484             484   (70, 80]
# 2   18      F     75            f          324             324   (70, 80]
# 3   30      M     95            m          900             900  (90, 100]
# 4   45      M     70            m         2025            2025   (60, 70]
# 5   50      F     85            f         2500            2500   (80, 85]
# 6   35      M     75            m         1225            1225   (70, 80]
# 7   20      F     90            f          400             400   (85, 90]
# 8   55      M     95            m         3025            3025  (90, 100]
# 9   40      M     85            m         1600            1600   (80, 85]

# %%
bin_names = ['Very low','low','medium','high','very high']
df['score_bins']=pd.cut(df['score'],bins=[60,70,80,85,90,100],labels=bin_names)

# %%
df
# Out:
#    age gender  score score_bins
# 0   25      M     90       high
# 1   22      F     80        low
# 2   18      F     75        low
# 3   30      M     95  very high
# 4   45      M     70   Very low
# 5   50      F     85     medium
# 6   35      M     75        low
# 7   20      F     90       high
# 8   55      M     95  very high
# 9   40      M     85     medium

# %%
age_bins = pd.qcut(df['age'],4)

# %%
df
# Out:
#    age gender  score score_bins
# 0   25      M     90       high
# 1   22      F     80        low
# 2   18      F     75        low
# 3   30      M     95  very high
# 4   45      M     70   Very low
# 5   50      F     85     medium
# 6   35      M     75        low
# 7   20      F     90       high
# 8   55      M     95  very high
# 9   40      M     85     medium

# %%
age_bins
# Out:
# 0      (22.75, 32.5]
# 1    (17.999, 22.75]
# 2    (17.999, 22.75]
# 3      (22.75, 32.5]
# 4      (43.75, 55.0]
# 5      (43.75, 55.0]
# 6      (32.5, 43.75]
# 7    (17.999, 22.75]
# 8      (43.75, 55.0]
# 9      (32.5, 43.75]
# Name: age, dtype: category
# Categories (4, interval[float64, right]): [(17.999, 22.75] < (22.75, 32.5] < (32.5, 43.75] < (43.75, 55.0]]

# %%
#Groupby

# %%
data = {'age': [25, 22, 18, 30, 45, 50, 35, 20, 55, 40],
        'gender': ['M', 'F', 'F', 'M', 'M', 'F', 'M', 'F', 'M', 'M'],
        'score': [90, 80, 75, 95, 70, 85, 75, 90, 95, 85]}
df = pd.DataFrame(data)

# %%
grouped = df.groupby('gender')

# %%
grouped

# %%
grouped['score'].mean()
# Out:
# gender
# F    82.5
# M    85.0
# Name: score, dtype: float64

# %%
df.groupby('gender')['score'].mean()
# Out:
# gender
# F    82.5
# M    85.0
# Name: score, dtype: float64

# %%
grouped['score'].agg(['mean','sum','count'])
# Out:
#         mean  sum  count
# gender
# F       82.5  330      4
# M       85.0  510      6

# %%
df.groupby('gender').agg({'age':'max','score':'mean'})
# Out:
#         age  score
# gender
# F        50   82.5
# M        55   85.0

# %%
df
# Out:
#    age gender  score
# 0   25      M     90
# 1   22      F     80
# 2   18      F     75
# 3   30      M     95
# 4   45      M     70
# 5   50      F     85
# 6   35      M     75
# 7   20      F     90
# 8   55      M     95
# 9   40      M     85

# %%
#Pivot Table

# %%
df.pivot_table(index='gender',
              values='score',
              aggfunc='mean')
# Out:
#         score
# gender
# F        82.5
# M        85.0

# %%
df.pivot_table(index=['gender'],
              values=['age','score'],
              aggfunc=['sum','mean','count'])
# Out:
#         sum             mean       count
#         age score        age score   age score
# gender
# F       110   330  27.500000  82.5     4     4
# M       230   510  38.333333  85.0     6     6

# %%
df
# Out:
#    age gender  score
# 0   25      M     90
# 1   22      F     80
# 2   18      F     75
# 3   30      M     95
# 4   45      M     70
# 5   50      F     85
# 6   35      M     75
# 7   20      F     90
# 8   55      M     95
# 9   40      M     85

# %%
#Nlargest and NSmallest

# %%
df['score'].nlargest(3)
# Out:
# 3    95
# 8    95
# 0    90
# Name: score, dtype: int64

# %%
df.nlargest(3,'score')
# Out:
#    age gender  score
# 3   30      M     95
# 8   55      M     95
# 0   25      M     90

# %%
df['score'].nsmallest(3)
# Out:
# 4    70
# 2    75
# 6    75
# Name: score, dtype: int64

# %%
df.nsmallest(3,'score')
# Out:
#    age gender  score
# 4   45      M     70
# 2   18      F     75
# 6   35      M     75

# %%
df
# Out:
#    age gender  score
# 0   25      M     90
# 1   22      F     80
# 2   18      F     75
# 3   30      M     95
# 4   45      M     70
# 5   50      F     85
# 6   35      M     75
# 7   20      F     90
# 8   55      M     95
# 9   40      M     85

# %%
df.query('age>25 and gender=="F"')
# Out:
#    age gender  score
# 5   50      F     85

# %%
df
# Out:
#    age gender  score
# 0   25      M     90
# 1   22      F     80
# 2   18      F     75
# 3   30      M     95
# 4   45      M     70
# 5   50      F     85
# 6   35      M     75
# 7   20      F     90
# 8   55      M     95
# 9   40      M     85

# %%
#Sort_Values

# %%
df.sort_values(by='age',ascending=False)
# Out:
#    age gender  score
# 8   55      M     95
# 5   50      F     85
# 4   45      M     70
# 9   40      M     85
# 6   35      M     75
# 3   30      M     95
# 0   25      M     90
# 1   22      F     80
# 7   20      F     90
# 2   18      F     75

# %%
df
# Out:
#    age gender  score
# 0   25      M     90
# 1   22      F     80
# 2   18      F     75
# 3   30      M     95
# 4   45      M     70
# 5   50      F     85
# 6   35      M     75
# 7   20      F     90
# 8   55      M     95
# 9   40      M     85

# %%
#Apply

# %%
df['gender_lower']=df['gender'].apply(str.lower)

# %%
df['age_squared']=df['age'].apply(lambda x : x**2)

# %%
df
# Out:
#    age gender  score gender_lower  age_squared
# 0   25      M     90            m          625
# 1   22      F     80            f          484
# 2   18      F     75            f          324
# 3   30      M     95            m          900
# 4   45      M     70            m         2025
# 5   50      F     85            f         2500
# 6   35      M     75            m         1225
# 7   20      F     90            f          400
# 8   55      M     95            m         3025
# 9   40      M     85            m         1600

# %%
#Functions

# %%
def age(x):
    return x**2

# %%
df['age_squared_uf']=df['age'].apply(age)

# %%
df
# Out:
#    age gender  score gender_lower  age_squared  age_squared_uf
# 0   25      M     90            m          625             625
# 1   22      F     80            f          484             484
# 2   18      F     75            f          324             324
# 3   30      M     95            m          900             900
# 4   45      M     70            m         2025            2025
# 5   50      F     85            f         2500            2500
# 6   35      M     75            m         1225            1225
# 7   20      F     90            f          400             400
# 8   55      M     95            m         3025            3025
# 9   40      M     85            m         1600            1600
