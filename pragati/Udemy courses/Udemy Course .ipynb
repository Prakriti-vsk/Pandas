# %% [markdown]
# #dataset link:-https://www.kaggle.com/datasets/andrewmvd/udemy-courses?select=udemy_courses.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('udemy_courses.xls',parse_dates=['published_timestamp'])

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
#display top 10 rows

# %%
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %%
#display last 10 rows

# %%
data.tail(10)
# Out:
#       course_id                                       course_title  \
# 3668     270976                             A how to guide in HTML
# 3669     679992                  Building Better APIs with GraphQL
# 3670     330900  Learn Grunt with Examples: Automate Your Front...
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3672     865438    jQuery UI in Action: Build 5 jQuery UI Projects
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3668      https://www.udemy.com/a-how-to-guide-in-html/    False      0
# 3669  https://www.udemy.com/building-better-apis-wit...     True     50
# ...

# %%
#3.Find shape of our dataset

# %%
data.shape
# Out:
# (3678, 12)

# %%
print("no. of rows",data.shape[0])
print("no. of columns",data.shape[1])
# Out:
# no. of rows 3678
# no. of columns 12

# %%
#4.Getting information of dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %%
#5.check null values in data set

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
print("Any missing values:-",data.isnull().values.any())
# Out:
# Any missing values:- False

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#6.Check for duplicate data and drop them

# %%
dup=data.duplicated().any()
print("Any duplicate values are there?",dup)
# Out:
# Any duplicate values are there? True

# %%
data=data.drop_duplicates()

# %%
dup=data.duplicated().any()
print("Any duplicate values are there?",dup)
# Out:
# Any duplicate values are there? False

# %%
#7.FInd out the number of courses per subejects

# %%
data.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance

# %%
data['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
sns.countplot(data['subject'])
# Out:
# <Axes: xlabel='count', ylabel='subject'>

# %%
sns.countplot(data['subject'])
plt.xlabel("Subjects")
plt.ylabel("Numbers of courses/subjects",fontsize=10)
plt.xticks(rotation=60)
plt.show()

# %%
#8.For which levels ,courses provides

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sns.countplot(data['level'])
plt.xlabel("Levels")
plt.ylabel("Numbers of courses/lavel",fontsize=10)
plt.xticks(rotation=60)
plt.show()

# %%
#9.Display count of paid and free courses

# %%
data['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %%
sns.countplot(data['is_paid'])
plt.xlabel("is_paid",fontsize=19)
plt.ylabel("Numbers of courses/is_paid",fontsize=15)
plt.xticks(rotation=60)
plt.show()

# %%
#10.Which course have more lecture free or paid

# %%
data.groupby(['is_paid']).average()

# %%
#11. which courses have a higher number of subscribers free or paid?

# %%
sns.barplot(x="is_paid",y="num_subscribers",data=data)
# Out:
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %%
#12. Which level has the highest number of subscribers

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
sns.barplot(x="level",y="num_subscribers",data=data)
plt.xticks(rotation=60)
plt.show()

# %%
#13.Find Most Popular COurses titles

# %%
data['num_subscribers'].max()
# Out:
# np.int64(268923)

# %%
data[data['num_subscribers'].max()==data['num_subscribers']]
# Out:
#       course_id                          course_title  \
# 2827      41295  Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 2827           268923         8629            45  All Levels
#
#       content_duration       published_timestamp          subject
# 2827              10.5 2013-02-14 07:03:41+00:00  Web Development

# %%
data[data['num_subscribers'].max()==data['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# # Display 10 most popular courses as per number of Subscirbes

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.sort_values(by="num_subscribers",ascending=False).head(10)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# ...         ...                                                ...
# 1234     185526                             MicroStation - Células
# 886     1087466  Stop Creditors from Harassing you and Avoid Ba...
# 887     1058852            Learn to trade using technical analysis
# 888     1083744  How to Invest Using ETFs from Former Wall Stre...
# 777     1215926                Kickstarter success in 5 easy steps
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# ...

# %%
top_10=data.sort_values(by="num_subscribers",ascending=False).head(10)

# %%
sns.barplot(x="num_subscribers",y="course_title",data=top_10)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %%
#15.Find the course which is having the highest number of reviews

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.barplot(x="subject",y="num_reviews",data=data)
# Out:
# <Axes: xlabel='subject', ylabel='num_reviews'>

# %%
#16.Does price affect number of reviews

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x="price",y="num_reviews",data=data)
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %%
#17.Find total number of courses related to python

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data[data['course_title'].str.contains('python',case=False)]
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %%
len(data[data['course_title'].str.contains('python',case=False)])
# Out:
# 29

# %%
#18.Display 10 Most popular python courses as per number of subscribers

# %%
data[data['course_title'].str.contains('python',case=False)].head(10)
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
#
#                                                     url  is_paid  price  \
# 14    https://www.udemy.com/hedge-fund-strategy-trad...     True    200
# 30    https://www.udemy.com/algorithmic-stock-tradin...     True     95
# ...

# %%
data[data['course_title'].str.contains('python',case=False)].sort_values(by="num_subscribers",ascending=False)
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
# 3392      70640  Python Programming: Create an Digital Marketpl...
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 3160     368340    Professional Python Web Development Using Flask
# ...

# %%
python=data[data['course_title'].str.contains('python',case=False)].sort_values(by="num_subscribers",ascending=False).head(10)

# %%
python
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...

# %%
sns.barplot(x="num_subscribers",y="course_title",data=python)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %%
#19.In which year highest number of course were posted?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data["Year"]=data['published_timestamp'].dt.year

# %%
data.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject  Year
# 0 2017-01-18 20:58:58+00:00  Business Finance  2017

# %%
sns.countplot(x='Year',data=data)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
#20. Display category-Wise Count posted subjects [Year Wise]

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'Year'],
#       dtype='object')

# %%
data.groupby('Year')['subject'].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       223
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
