# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data=pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
#Display First 5 Rows

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#display Last 5 Rows

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
#Print Random % ROws Of The DataSet

# %%
data.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 373  382-25-8917      C  Naypyitaw        Normal    Male  Fashion accessories
# 937  361-85-2571      A     Yangon        Normal  Female    Sports and travel
# 525  719-89-8991      A     Yangon        Member  Female    Sports and travel
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
# 709  445-30-9252      A     Yangon        Normal    Male    Sports and travel
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time  Payment  \
# 373       42.08         6  12.6240  265.1040  1/29/2019  12:25     Cash
# 937       89.48         5  22.3700  469.7700  3/30/2019  10:18     Cash
# 525       91.41         5  22.8525  479.9025  2/25/2019  16:03  Ewallet
# 999       88.34         7  30.9190  649.2990  2/18/2019  13:28     Cash
# 709       25.70         3   3.8550   80.9550  1/17/2019  17:59  Ewallet
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
##FInd Shape OF our DataSet

# %%
data.shape
# Out:
# (1000, 17)

# %%
print("Number Of Rows:",data.shape[0])
print("Number Of Columns:",data.shape[1])
# Out:
# Number Of Rows: 1000
# Number Of Columns: 17

# %%
#Check NUll Values From The Dataset

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#Get Information of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#Get Overall Statistics about the dataset

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
#Unvariate Analysis

# %%
#1.Find Aggregate Sales Among Branches.(Categorial Column)

# %%
cat=[]
num=[]
for column in data.columns:
    if data[column].nunique() > 10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.countplot(data['Branch'])
# Out:
# <Axes: xlabel='count', ylabel='Branch'>

# %%
data['Branch'].value_counts().plot(kind="pie",autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['Branch'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Branch'>

# %%
#2.Find The Most Popular Payment Method Used By Customers (Categorial Column)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data['Payment'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Payment'>

# %%
#3.Find The Distribution of Customer Rating.(Numerical Column)

# %%
sns.distplot(data['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
data['Rating'].skew()
# Out:
# np.float64(0.00900964876573073)

# %%
#Find The Distribution Of Cost Of Good Sold (Numeric Column)

# %%
sns.distplot(data['cogs'])
# Out:
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
data['cogs'].skew()
# Out:
# np.float64(0.8925698049581418)

# %%
sns.boxplot(data['cogs'])
# Out:
# <Axes: ylabel='cogs'>

# %%
## Bivariate Analysis/Multivariate Analysis

# %%
#1.Does The Cost Of Good solds Affect The Rating That The Customers Provide(NUmerical-Numerical)

# %%
sns.scatterplot(x=data['cogs'], y=data['Rating'])
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %%
#2.Does Gross Income Affect The Ratings That The Customers Provide?(Numerical-Numercial)

# %%
sns.scatterplot(x=data['gross income'], y=data['Rating'])
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %%
#FInd The Most Profitable Branch As Per Gross Income(NUmerical=Categorical)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.barplot(x='Branch', y='gross income', data=data)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(x='Branch', y='gross income', hue='City', data=data)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
#4.Is there any Relationship Between Gender And Gross Income?

# %%
sns.boxplot(x='Gender', y='gross income', hue='Customer type', data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
#5.Find The Product Line That Generates The most Income .(Numerical-Categorical)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(x='Product line',y='gross income',data=data)
plt.xticks(rotation=75)
plt.show()

# %%
#6.Find The Highest Unit Price In The Product Line .(Numerical-Categorical)

# %%
sns.barplot(x='Product line',y='Unit price',data=data)
plt.xticks(rotation=65)
plt.show()

# %%
#7.Find The Different Payment Method Used By Customers Citywise.(Categorical-Categorical)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
pd.crosstab(data['City'],data['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(data['City'],data['Payment']))
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
#8.Which Product Line Is Purchased In The Highest Quantity?

# %%
data.groupby('Product line').sum()['Quantity']
# Out:
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64

# %%
(data.groupby('Product line').sum()['Quantity']).plot(kind='bar')
# Out:
# <Axes: xlabel='Product line'>

# %%
#9. Display Daily sales by Day Of The Week

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['Day of Week'] = data['Date'].dt.dayofweek

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data['Date'].dt.dayofweek
# Out:
# 0      5
# 1      4
# 2      6
# 3      6
# 4      4
#       ..
# 995    1
# 996    5
# 997    5
# 998    4
# 999    0
# Name: Date, Length: 1000, dtype: int32

# %%
dw_mapping = {0:'Mon',
             1:'Tue',
           2:'Wed',
             3:'Thu',
             4:'Fri',
             6:'Sat',
             7:'Sun'}

# %%
dw_mapping
# Out:
# {0: 'Mon', 1: 'Tue', 2: 'Wed', 3: 'Thu', 4: 'Fri', 6: 'Sat', 7: 'Sun'}

# %%
data['Day_of_week']=data['Date'].dt.dayofweek.map(dw_mapping)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Day of Week', 'Day_of_week', 'month'],
#       dtype='object')

# %%
data['Day_of_week'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Day_of_week'>

# %%
#What Will Be The Highest Months For Sales

# %%
month_mapping ={1:'January',
               2:'February',
               3:'March'}

# %%
data['month']=data['Date'].dt.month.map(month_mapping)

# %%
data.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time  Payment    cogs  \
# 0       74.69         7  26.1415  548.9715 2019-01-05  13:08  Ewallet  522.83
#
#    gross margin percentage  gross income  Rating  Day of Week Day_of_week  \
# 0                 4.761905       26.1415     9.1            5         NaN
#
#      month
# 0  January

# %%
data['month'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='month'>
